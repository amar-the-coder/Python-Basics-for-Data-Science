# %%
## dataset
import pandas as pd 
csv = pd.read_csv("C:\\Users\\amarj\\Amarjeet Python Case Studies DataSets\\1. Basic Data Manipulation\\student-mat.csv")
csv
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# # Practice of Slicing

# %% [markdown]
# # In Series:-------

# %%
s1 = pd.Series([1, 2, 3, 4, 5])
s2 = pd.Series([100, 200, 300], index=['Jan', 'Feb', 'March'])
s3 = pd.Series([10, 100, 1000], index=[1001, 1002, 1003])
print(s1)
print()
print(s2)
print()
print(s3)
print()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
#
# Jan      100
# Feb      200
# March    300
# dtype: int64
#
# 1001      10
# 1002     100
# 1003    1000
# dtype: int64

# %%
## to access values---
s1[2] ## using defalut index
s2['Jan'] ## using user defined index
# Out:
# 100

# %%
## in s1 slicing
s1[0:3] # - from 0 to 2
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
# s1[-1] # negative does not work in series

# %%
s2
# Out:
# Jan      100
# Feb      200
# March    300
# dtype: int64

# %%
s2['Jan':'Feb'] ## both column names are inclusive ---
# Out:
# Jan    100
# Feb    200
# dtype: int64

# %% [markdown]
# ## now we have loc and iloc
#
# ## Accessing data from a Series
#
#
# Because a Series has two different kinds of indexes in the backend. Just using simple [] doesn't
# work anymore. It causes confusion.
#
# So to get rid of this confusion, pandas introducted two attributes.
#
# 1. `.loc[]` - use to access data from user defined index
#             - while slicing, .loc is inclusive
#
# 2. `.iloc[]` - use to access data from the default index
#             - while slicing, last value will be excluded.

# %%
s2
# Out:
# Jan      100
# Feb      200
# March    300
# dtype: int64

# %%
# using loc now -- it always works with user defined functions:-
s2.loc['Jan':'Feb']
# Out:
# Jan    100
# Feb    200
# dtype: int64

# %%
s2.loc['Jan':'March']
# Out:
# Jan      100
# Feb      200
# March    300
# dtype: int64

# %%
s2.loc['Feb':]
# Out:
# Feb      200
# March    300
# dtype: int64

# %%
s2
# Out:
# Jan      100
# Feb      200
# March    300
# dtype: int64

# %%
# using iloc
s2.iloc[0] # it works on default index
# Out:
# 100

# %%
s2.iloc[0:3]
# Out:
# Jan      100
# Feb      200
# March    300
# dtype: int64

# %%
s4 = pd.Series([100, 200, 300], index=[1, 2, 3])

s4
# Out:
# 1    100
# 2    200
# 3    300
# dtype: int64

# %%
# s4[0] ## because it gets confused what to decide ---so error

# %%
s4
# Out:
# 1    100
# 2    200
# 3    300
# dtype: int64

# %%
s4.iloc[0:2]
# Out:
# 1    100
# 2    200
# dtype: int64

# %%
s4.loc[3]
# Out:
# 300

# %% [markdown]
# # now in DataFrame

# %%
csv = pd.read_csv("C:\\Users\\amarj\\Amarjeet Python Case Studies DataSets\\1. Basic Data Manipulation\\FMCG_Company_Data_2019.csv")
csv
# Out:
#      Month  FaceCream  FaceWash  ToothPaste   Soap  Shampo  Moisturizer  \
# 0   Jan-19       2500      1500        5200   9200    1200         1500
# 1   Feb-19       2630      1200        5100   6100    2100         1200
# 2   Mar-19       2140      1340        4550   9550    3550         1340
# 3   Apr-19       3400      1130        5870   8870    1870         1130
# 4   May-19       3600      1740        4560   7760    1560         1740
# 5   Jun-19       2760      1555        4890   7490    1890         1555
# 6   Jul-19       2980      1120        4780   8980    1780         1120
# 7   Aug-19       3700      1400        5860   9960    2860         1400
# 8   Sep-19       3540      1780        6100   8100    2100         1780
# 9   Oct-19       1990      1890        8300  10300    2300         1890
# 10  Nov-19       2340      2100        7300  13300    2400         2100
# 11  Dec-19       2900      1760        7400  14400    1800         1760
#
# ...

# %%
csv
# Out:
#      Month  FaceCream  FaceWash  ToothPaste   Soap  Shampo  Moisturizer  \
# 0   Jan-19       2500      1500        5200   9200    1200         1500
# 1   Feb-19       2630      1200        5100   6100    2100         1200
# 2   Mar-19       2140      1340        4550   9550    3550         1340
# 3   Apr-19       3400      1130        5870   8870    1870         1130
# 4   May-19       3600      1740        4560   7760    1560         1740
# 5   Jun-19       2760      1555        4890   7490    1890         1555
# 6   Jul-19       2980      1120        4780   8980    1780         1120
# 7   Aug-19       3700      1400        5860   9960    2860         1400
# 8   Sep-19       3540      1780        6100   8100    2100         1780
# 9   Oct-19       1990      1890        8300  10300    2300         1890
# 10  Nov-19       2340      2100        7300  13300    2400         2100
# 11  Dec-19       2900      1760        7400  14400    1800         1760
#
# ...

# %% [markdown]
# ## Accessing columns
#
# 4 ways that pandas provides of accessing columns.
#
# 1. `[]` - this syntax takes values in only a single dimension
# 2. `.loc[:, column_name]`  - works in two dimension
# 3. `.iloc[:, coloumn_index]`
# 4. `file_name[column_name]`

# %%
csv['Month']  ## it will always come in series
# Out:
# 0     Jan-19
# 1     Feb-19
# 2     Mar-19
# 3     Apr-19
# 4     May-19
# 5     Jun-19
# 6     Jul-19
# 7     Aug-19
# 8     Sep-19
# 9     Oct-19
# 10    Nov-19
# 11    Dec-19
# Name: Month, dtype: object

# %%
csv.info
# Out:
# <bound method DataFrame.info of      Month  FaceCream  FaceWash  ToothPaste   Soap  Shampo  Moisturizer  \
# 0   Jan-19       2500      1500        5200   9200    1200         1500
# 1   Feb-19       2630      1200        5100   6100    2100         1200
# 2   Mar-19       2140      1340        4550   9550    3550         1340
# 3   Apr-19       3400      1130        5870   8870    1870         1130
# 4   May-19       3600      1740        4560   7760    1560         1740
# 5   Jun-19       2760      1555        4890   7490    1890         1555
# 6   Jul-19       2980      1120        4780   8980    1780         1120
# 7   Aug-19       3700      1400        5860   9960    2860         1400
# 8   Sep-19       3540      1780        6100   8100    2100         1780
# 9   Oct-19       1990      1890        8300  10300    2300         1890
# 10  Nov-19       2340      2100        7300  13300    2400         2100
# 11  Dec-19       2900      1760        7400  14400    1800         1760
#
# ...

# %%
csv.describe()
# Out:
#          FaceCream     FaceWash   ToothPaste          Soap       Shampo  \
# count    12.000000    12.000000    12.000000     12.000000    12.000000
# mean   2873.333333  1542.916667  5825.833333   9500.833333  2117.500000
# std     584.595172   316.733745  1242.032486   2348.095779   617.724931
# min    1990.000000  1120.000000  4550.000000   6100.000000  1200.000000
# 25%    2460.000000  1305.000000  4862.500000   8015.000000  1795.000000
# 50%    2830.000000  1527.500000  5530.000000   9090.000000  1995.000000
# 75%    3435.000000  1765.000000  6400.000000  10045.000000  2325.000000
# max    3700.000000  2100.000000  8300.000000  14400.000000  3550.000000
#
#        Moisturizer  Total_Units  Total_Revenue   Total_Profit
# count    12.000000     12.00000   1.200000e+01      12.000000
# mean   1542.916667  26027.50000   4.039514e+06  260275.000000
# std     316.733745   7014.36594   1.300849e+06   70143.659404
# min    1120.000000  18330.00000   2.857866e+06  183300.000000
# ...

# %%
csv
# Out:
#      Month  FaceCream  FaceWash  ToothPaste   Soap  Shampo  Moisturizer  \
# 0   Jan-19       2500      1500        5200   9200    1200         1500
# 1   Feb-19       2630      1200        5100   6100    2100         1200
# 2   Mar-19       2140      1340        4550   9550    3550         1340
# 3   Apr-19       3400      1130        5870   8870    1870         1130
# 4   May-19       3600      1740        4560   7760    1560         1740
# 5   Jun-19       2760      1555        4890   7490    1890         1555
# 6   Jul-19       2980      1120        4780   8980    1780         1120
# 7   Aug-19       3700      1400        5860   9960    2860         1400
# 8   Sep-19       3540      1780        6100   8100    2100         1780
# 9   Oct-19       1990      1890        8300  10300    2300         1890
# 10  Nov-19       2340      2100        7300  13300    2400         2100
# 11  Dec-19       2900      1760        7400  14400    1800         1760
#
# ...

# %%
## now slicing ----
csv.loc[:,:]
# Out:
#      Month  FaceCream  FaceWash  ToothPaste   Soap  Shampo  Moisturizer  \
# 0   Jan-19       2500      1500        5200   9200    1200         1500
# 1   Feb-19       2630      1200        5100   6100    2100         1200
# 2   Mar-19       2140      1340        4550   9550    3550         1340
# 3   Apr-19       3400      1130        5870   8870    1870         1130
# 4   May-19       3600      1740        4560   7760    1560         1740
# 5   Jun-19       2760      1555        4890   7490    1890         1555
# 6   Jul-19       2980      1120        4780   8980    1780         1120
# 7   Aug-19       3700      1400        5860   9960    2860         1400
# 8   Sep-19       3540      1780        6100   8100    2100         1780
# 9   Oct-19       1990      1890        8300  10300    2300         1890
# 10  Nov-19       2340      2100        7300  13300    2400         2100
# 11  Dec-19       2900      1760        7400  14400    1800         1760
#
# ...

# %%
csv.loc[:,'Month':'Shampo']
# Out:
#      Month  FaceCream  FaceWash  ToothPaste   Soap  Shampo
# 0   Jan-19       2500      1500        5200   9200    1200
# 1   Feb-19       2630      1200        5100   6100    2100
# 2   Mar-19       2140      1340        4550   9550    3550
# 3   Apr-19       3400      1130        5870   8870    1870
# 4   May-19       3600      1740        4560   7760    1560
# 5   Jun-19       2760      1555        4890   7490    1890
# 6   Jul-19       2980      1120        4780   8980    1780
# 7   Aug-19       3700      1400        5860   9960    2860
# 8   Sep-19       3540      1780        6100   8100    2100
# 9   Oct-19       1990      1890        8300  10300    2300
# 10  Nov-19       2340      2100        7300  13300    2400
# 11  Dec-19       2900      1760        7400  14400    1800

# %%
csv.loc[0:5,'Soap':'Shampo']
# Out:
#    Soap  Shampo
# 0  9200    1200
# 1  6100    2100
# 2  9550    3550
# 3  8870    1870
# 4  7760    1560
# 5  7490    1890

# %%
csv.iloc[0:7,1:5]
# Out:
#    FaceCream  FaceWash  ToothPaste  Soap
# 0       2500      1500        5200  9200
# 1       2630      1200        5100  6100
# 2       2140      1340        4550  9550
# 3       3400      1130        5870  8870
# 4       3600      1740        4560  7760
# 5       2760      1555        4890  7490
# 6       2980      1120        4780  8980

# %%
csv[3:9]
# Out:
#     Month  FaceCream  FaceWash  ToothPaste  Soap  Shampo  Moisturizer  \
# 3  Apr-19       3400      1130        5870  8870    1870         1130
# 4  May-19       3600      1740        4560  7760    1560         1740
# 5  Jun-19       2760      1555        4890  7490    1890         1555
# 6  Jul-19       2980      1120        4780  8980    1780         1120
# 7  Aug-19       3700      1400        5860  9960    2860         1400
# 8  Sep-19       3540      1780        6100  8100    2100         1780
#
#    Total_Units  Total_Revenue  Total_Profit
# 3        22270        2890646        222700
# 4        20960        2997280        209600
# 5        20140        2857866        201400
# 6        29550        5735655        295500
# 7        36140        5196932        361400
# 8        23400        3060720        234000

# %%
# we can also pass a list as column names
# we have to make sure that in loc--- we have to pass a list of column names
# we have to make sure that in iloc--- we have to pass a list of column index

csv[['FaceCream','FaceWash','ToothPaste']]
# Out:
#     FaceCream  FaceWash  ToothPaste
# 0        2500      1500        5200
# 1        2630      1200        5100
# 2        2140      1340        4550
# 3        3400      1130        5870
# 4        3600      1740        4560
# 5        2760      1555        4890
# 6        2980      1120        4780
# 7        3700      1400        5860
# 8        3540      1780        6100
# 9        1990      1890        8300
# 10       2340      2100        7300
# 11       2900      1760        7400

# %%
csv.loc[2,'FaceCream']
# Out:
# 2140

# %%
# using loc
csv.loc[:,['FaceCream','ToothPaste']]
# Out:
#     FaceCream  ToothPaste
# 0        2500        5200
# 1        2630        5100
# 2        2140        4550
# 3        3400        5870
# 4        3600        4560
# 5        2760        4890
# 6        2980        4780
# 7        3700        5860
# 8        3540        6100
# 9        1990        8300
# 10       2340        7300
# 11       2900        7400

# %%
# using loc
csv.loc[3:5,'Shampo':'Total_Profit']
# Out:
#    Shampo  Moisturizer  Total_Units  Total_Revenue  Total_Profit
# 3    1870         1130        22270        2890646        222700
# 4    1560         1740        20960        2997280        209600
# 5    1890         1555        20140        2857866        201400

# %%
csv
# Out:
#      Month  FaceCream  FaceWash  ToothPaste   Soap  Shampo  Moisturizer  \
# 0   Jan-19       2500      1500        5200   9200    1200         1500
# 1   Feb-19       2630      1200        5100   6100    2100         1200
# 2   Mar-19       2140      1340        4550   9550    3550         1340
# 3   Apr-19       3400      1130        5870   8870    1870         1130
# 4   May-19       3600      1740        4560   7760    1560         1740
# 5   Jun-19       2760      1555        4890   7490    1890         1555
# 6   Jul-19       2980      1120        4780   8980    1780         1120
# 7   Aug-19       3700      1400        5860   9960    2860         1400
# 8   Sep-19       3540      1780        6100   8100    2100         1780
# 9   Oct-19       1990      1890        8300  10300    2300         1890
# 10  Nov-19       2340      2100        7300  13300    2400         2100
# 11  Dec-19       2900      1760        7400  14400    1800         1760
#
# ...

# %%
# using iloc
csv.iloc[2:6,3:5]
# Out:
#    ToothPaste  Soap
# 2        4550  9550
# 3        5870  8870
# 4        4560  7760
# 5        4890  7490

# %%
# using iloc
csv.iloc[2:12,3:8]
# Out:
#     ToothPaste   Soap  Shampo  Moisturizer  Total_Units
# 2         4550   9550    3550         1340        22470
# 3         5870   8870    1870         1130        22270
# 4         4560   7760    1560         1740        20960
# 5         4890   7490    1890         1555        20140
# 6         4780   8980    1780         1120        29550
# 7         5860   9960    2860         1400        36140
# 8         6100   8100    2100         1780        23400
# 9         8300  10300    2300         1890        26670
# 10        7300  13300    2400         2100        41280
# 11        7400  14400    1800         1760        30020

# %%
csv
# Out:
#      Month  FaceCream  FaceWash  ToothPaste   Soap  Shampo  Moisturizer  \
# 0   Jan-19       2500      1500        5200   9200    1200         1500
# 1   Feb-19       2630      1200        5100   6100    2100         1200
# 2   Mar-19       2140      1340        4550   9550    3550         1340
# 3   Apr-19       3400      1130        5870   8870    1870         1130
# 4   May-19       3600      1740        4560   7760    1560         1740
# 5   Jun-19       2760      1555        4890   7490    1890         1555
# 6   Jul-19       2980      1120        4780   8980    1780         1120
# 7   Aug-19       3700      1400        5860   9960    2860         1400
# 8   Sep-19       3540      1780        6100   8100    2100         1780
# 9   Oct-19       1990      1890        8300  10300    2300         1890
# 10  Nov-19       2340      2100        7300  13300    2400         2100
# 11  Dec-19       2900      1760        7400  14400    1800         1760
#
# ...

# %%
## access in these form to access a particular value:-
csv['Month'][0]
# Out:
# 'Jan-19'

# %%
## now access in negative values--:
csv.iloc[:,-2:]
# Out:
#     Total_Revenue  Total_Profit
# 0         3584890        211000
# 1         2864979        183300
# 2         4058082        224700
# 3         2890646        222700
# 4         2997280        209600
# 5         2857866        201400
# 6         5735655        295500
# 7         5196932        361400
# 8         3060720        234000
# 9         4661916        266700
# 10        6794688        412800
# 11        3770512        300200

# %%
csv
# Out:
#      Month  FaceCream  FaceWash  ToothPaste   Soap  Shampo  Moisturizer  \
# 0   Jan-19       2500      1500        5200   9200    1200         1500
# 1   Feb-19       2630      1200        5100   6100    2100         1200
# 2   Mar-19       2140      1340        4550   9550    3550         1340
# 3   Apr-19       3400      1130        5870   8870    1870         1130
# 4   May-19       3600      1740        4560   7760    1560         1740
# 5   Jun-19       2760      1555        4890   7490    1890         1555
# 6   Jul-19       2980      1120        4780   8980    1780         1120
# 7   Aug-19       3700      1400        5860   9960    2860         1400
# 8   Sep-19       3540      1780        6100   8100    2100         1780
# 9   Oct-19       1990      1890        8300  10300    2300         1890
# 10  Nov-19       2340      2100        7300  13300    2400         2100
# 11  Dec-19       2900      1760        7400  14400    1800         1760
#
# ...

# %% [markdown]
# # renaming columns:-

# %%
df = pd.read_csv("C:/Users/amarj/Amarjeet Python Case Studies DataSets/1. Basic Data Manipulation/student-por.csv")

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
# 1. 
df.rename(columns={'school':'school_name','age':'age_number'})
# Out:
#     school_name sex  age_number address famsize Pstatus  Medu  Fedu      Mjob  \
# 0            GP   F          18       U     GT3       A     4     4   at_home
# 1            GP   F          17       U     GT3       T     1     1   at_home
# 2            GP   F          15       U     LE3       T     1     1   at_home
# 3            GP   F          15       U     GT3       T     4     2    health
# 4            GP   F          16       U     GT3       T     3     3     other
# ..          ...  ..         ...     ...     ...     ...   ...   ...       ...
# 644          MS   F          19       R     GT3       T     2     3  services
# 645          MS   F          18       U     LE3       T     3     1   teacher
# 646          MS   F          18       U     GT3       T     1     1     other
# 647          MS   M          17       U     LE3       T     3     1  services
# 648          MS   M          18       R     LE3       T     3     2  services
#
# ...

# %%
# 2. 
# df.columns = ['1','2'] ## shpould be equal to the no of columns

# %%
# question : create a new list of columns that are all uppercase
df.columns.str.upper()
# Out:
# Index(['SCHOOL', 'SEX', 'AGE', 'ADDRESS', 'FAMSIZE', 'PSTATUS', 'MEDU', 'FEDU',
#        'MJOB', 'FJOB', 'REASON', 'GUARDIAN', 'TRAVELTIME', 'STUDYTIME',
#        'FAILURES', 'SCHOOLSUP', 'FAMSUP', 'PAID', 'ACTIVITIES', 'NURSERY',
#        'HIGHER', 'INTERNET', 'ROMANTIC', 'FAMREL', 'FREETIME', 'GOOUT', 'DALC',
#        'WALC', 'HEALTH', 'ABSENCES', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
[column.upper() for column in df.columns] # using list comprehension
# Out:
# ['SCHOOL',
#  'SEX',
#  'AGE',
#  'ADDRESS',
#  'FAMSIZE',
#  'PSTATUS',
#  'MEDU',
#  'FEDU',
#  'MJOB',
#  'FJOB',
#  'REASON',
#  'GUARDIAN',
#  'TRAVELTIME',
#  'STUDYTIME',
#  'FAILURES',
#  'SCHOOLSUP',
#  'FAMSUP',
#  'PAID',
#  'ACTIVITIES',
#  'NURSERY',
#  'HIGHER',
#  'INTERNET',
#  'ROMANTIC',
#  'FAMREL',
#  'FREETIME',
#  'GOOUT',
#  'DALC',
#  'WALC',
#  'HEALTH',
#  'ABSENCES',
#  'G1',
#  'G2',
#  'G3']

# %% [markdown]
# # creating new columns

# %%
#1 
df['new_col'] = df['G1']+df['G2']+df['G3']

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
# using loc 
df.loc[: , 'new_col_1'] = -1

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
# 3. Insert
df.insert(0,'new_col_',100)
df
# Out:
#      new_col_ school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0         100     GP   F   18       U     GT3       A     4     4   at_home
# 1         100     GP   F   17       U     GT3       T     1     1   at_home
# 2         100     GP   F   15       U     LE3       T     1     1   at_home
# 3         100     GP   F   15       U     GT3       T     4     2    health
# 4         100     GP   F   16       U     GT3       T     3     3     other
# ..        ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 644       100     MS   F   19       R     GT3       T     2     3  services
# 645       100     MS   F   18       U     LE3       T     3     1   teacher
# 646       100     MS   F   18       U     GT3       T     1     1     other
# 647       100     MS   M   17       U     LE3       T     3     1  services
# 648       100     MS   M   18       R     LE3       T     3     2  services
#
# ...

# %%
# 4. assign 
df.assign(col1=10,col2=23)
# Out:
#      new_col_ school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0         100     GP   F   18       U     GT3       A     4     4   at_home
# 1         100     GP   F   17       U     GT3       T     1     1   at_home
# 2         100     GP   F   15       U     LE3       T     1     1   at_home
# 3         100     GP   F   15       U     GT3       T     4     2    health
# 4         100     GP   F   16       U     GT3       T     3     3     other
# ..        ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 644       100     MS   F   19       R     GT3       T     2     3  services
# 645       100     MS   F   18       U     LE3       T     3     1   teacher
# 646       100     MS   F   18       U     GT3       T     1     1     other
# 647       100     MS   M   17       U     LE3       T     3     1  services
# 648       100     MS   M   18       R     LE3       T     3     2  services
#
# ...

# %%
df
# Out:
#      new_col_ school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0         100     GP   F   18       U     GT3       A     4     4   at_home
# 1         100     GP   F   17       U     GT3       T     1     1   at_home
# 2         100     GP   F   15       U     LE3       T     1     1   at_home
# 3         100     GP   F   15       U     GT3       T     4     2    health
# 4         100     GP   F   16       U     GT3       T     3     3     other
# ..        ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 644       100     MS   F   19       R     GT3       T     2     3  services
# 645       100     MS   F   18       U     LE3       T     3     1   teacher
# 646       100     MS   F   18       U     GT3       T     1     1     other
# 647       100     MS   M   17       U     LE3       T     3     1  services
# 648       100     MS   M   18       R     LE3       T     3     2  services
#
# ...

# %%
# setting the user defined index

# new_col
df['index_column'] = range(0,649,1)

# %%
# set index
df.set_index('index_column',inplace=True)

# %%
df.drop('new_col_',axis=1,inplace=True)

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df
# Out:
#              school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# index_column
# 0                GP   F   18       U     GT3       A     4     4   at_home
# 1                GP   F   17       U     GT3       T     1     1   at_home
# 2                GP   F   15       U     LE3       T     1     1   at_home
# 3                GP   F   15       U     GT3       T     4     2    health
# 4                GP   F   16       U     GT3       T     3     3     other
# ...             ...  ..  ...     ...     ...     ...   ...   ...       ...
# 644              MS   F   19       R     GT3       T     2     3  services
# 645              MS   F   18       U     LE3       T     3     1   teacher
# 646              MS   F   18       U     GT3       T     1     1     other
# 647              MS   M   17       U     LE3       T     3     1  services
# 648              MS   M   18       R     LE3       T     3     2  services
#
# ...

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3', 'new_col', 'new_col_1'],
#       dtype='object')

# %%
df.columns[9]
# Out:
# 'Fjob'

# %%
df['reason']
# Out:
# index_column
# 0      course
# 1      course
# 2       other
# 3        home
# 4        home
#         ...
# 644    course
# 645    course
# 646    course
# 647    course
# 648    course
# Name: reason, Length: 649, dtype: object

# %%
df
# Out:
#              school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# index_column
# 0                GP   F   18       U     GT3       A     4     4   at_home
# 1                GP   F   17       U     GT3       T     1     1   at_home
# 2                GP   F   15       U     LE3       T     1     1   at_home
# 3                GP   F   15       U     GT3       T     4     2    health
# 4                GP   F   16       U     GT3       T     3     3     other
# ...             ...  ..  ...     ...     ...     ...   ...   ...       ...
# 644              MS   F   19       R     GT3       T     2     3  services
# 645              MS   F   18       U     LE3       T     3     1   teacher
# 646              MS   F   18       U     GT3       T     1     1     other
# 647              MS   M   17       U     LE3       T     3     1  services
# 648              MS   M   18       R     LE3       T     3     2  services
#
# ...

# %%
## boolean indexing

# 1 find the records where Pstatus is T

df[df.Pstatus=='A']
# Out:
#              school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# index_column
# 0                GP   F   18       U     GT3       A     4     4   at_home
# 7                GP   F   17       U     GT3       A     4     4     other
# 8                GP   M   15       U     LE3       A     3     2  services
# 14               GP   M   15       U     GT3       A     2     2     other
# 28               GP   M   16       U     LE3       A     3     4  services
# ...             ...  ..  ...     ...     ...     ...   ...   ...       ...
# 607              MS   F   17       R     LE3       A     2     1  services
# 608              MS   F   18       U     LE3       A     1     1   at_home
# 610              MS   F   19       R     GT3       A     1     1   at_home
# 615              MS   F   17       U     LE3       A     3     2  services
# 618              MS   F   18       R     LE3       A     1     2   at_home
#
# ...

# %%
# 2 get the all records of Pstatus where goout is 4

## using square bracket
df[df.goout==4]['Pstatus']

## using loc
df.loc[df.goout==4,'Pstatus']
# Out:
# index_column
# 0      A
# 6      T
# 7      A
# 15     T
# 23     T
#       ..
# 630    T
# 635    T
# 636    T
# 642    T
# 645    T
# Name: Pstatus, Length: 141, dtype: object

# %%
df
# Out:
#              school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# index_column
# 0                GP   F   18       U     GT3       A     4     4   at_home
# 1                GP   F   17       U     GT3       T     1     1   at_home
# 2                GP   F   15       U     LE3       T     1     1   at_home
# 3                GP   F   15       U     GT3       T     4     2    health
# 4                GP   F   16       U     GT3       T     3     3     other
# ...             ...  ..  ...     ...     ...     ...   ...   ...       ...
# 644              MS   F   19       R     GT3       T     2     3  services
# 645              MS   F   18       U     LE3       T     3     1   teacher
# 646              MS   F   18       U     GT3       T     1     1     other
# 647              MS   M   17       U     LE3       T     3     1  services
# 648              MS   M   18       R     LE3       T     3     2  services
#
# ...

# %%
## get the records age between 15 to 17
df[df.age.between(15,17)]
# Out:
#              school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# index_column
# 1                GP   F   17       U     GT3       T     1     1   at_home
# 2                GP   F   15       U     LE3       T     1     1   at_home
# 3                GP   F   15       U     GT3       T     4     2    health
# 4                GP   F   16       U     GT3       T     3     3     other
# 5                GP   M   16       U     LE3       T     4     3  services
# ...             ...  ..  ...     ...     ...     ...   ...   ...       ...
# 629              MS   F   17       R     GT3       T     1     2     other
# 635              MS   F   17       R     GT3       T     3     1   at_home
# 638              MS   M   17       U     GT3       T     2     3     other
# 642              MS   F   17       U     GT3       T     4     3   teacher
# 647              MS   M   17       U     LE3       T     3     1  services
#
# ...

# %%
## get all the records where mjib is at_home and other
df[df.Mjob.isin(['at_home','other'])]
# Out:
#              school sex  age address famsize Pstatus  Medu  Fedu     Mjob  \
# index_column
# 0                GP   F   18       U     GT3       A     4     4  at_home
# 1                GP   F   17       U     GT3       T     1     1  at_home
# 2                GP   F   15       U     LE3       T     1     1  at_home
# 4                GP   F   16       U     GT3       T     3     3    other
# 6                GP   M   16       U     LE3       T     2     2    other
# ...             ...  ..  ...     ...     ...     ...   ...   ...      ...
# 638              MS   M   17       U     GT3       T     2     3    other
# 639              MS   M   19       R     GT3       T     1     1    other
# 640              MS   M   18       R     GT3       T     4     2    other
# 641              MS   F   18       R     GT3       T     2     2  at_home
# 646              MS   F   18       U     GT3       T     1     1    other
#
# ...

# %%
## str functions
df['Mjob'] = df.Mjob.str.upper()

# %%
df
# Out:
#              school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# index_column
# 0                GP   F   18       U     GT3       A     4     4   AT_HOME
# 1                GP   F   17       U     GT3       T     1     1   AT_HOME
# 2                GP   F   15       U     LE3       T     1     1   AT_HOME
# 3                GP   F   15       U     GT3       T     4     2    HEALTH
# 4                GP   F   16       U     GT3       T     3     3     OTHER
# ...             ...  ..  ...     ...     ...     ...   ...   ...       ...
# 644              MS   F   19       R     GT3       T     2     3  SERVICES
# 645              MS   F   18       U     LE3       T     3     1   TEACHER
# 646              MS   F   18       U     GT3       T     1     1     OTHER
# 647              MS   M   17       U     LE3       T     3     1  SERVICES
# 648              MS   M   18       R     LE3       T     3     2  SERVICES
#
# ...

# %%
df
# Out:
#              school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# index_column
# 0                GP   F   18       U     GT3       A     4     4   AT_HOME
# 1                GP   F   17       U     GT3       T     1     1   AT_HOME
# 2                GP   F   15       U     LE3       T     1     1   AT_HOME
# 3                GP   F   15       U     GT3       T     4     2    HEALTH
# 4                GP   F   16       U     GT3       T     3     3     OTHER
# ...             ...  ..  ...     ...     ...     ...   ...   ...       ...
# 644              MS   F   19       R     GT3       T     2     3  SERVICES
# 645              MS   F   18       U     LE3       T     3     1   TEACHER
# 646              MS   F   18       U     GT3       T     1     1     OTHER
# 647              MS   M   17       U     LE3       T     3     1  SERVICES
# 648              MS   M   18       R     LE3       T     3     2  SERVICES
#
# ...

# %%
ds = pd.read_csv("C:/Users/amarj/Amarjeet Python Case Studies DataSets/1. Basic Data Manipulation/Online_Retail.csv",encoding='latin1')

# %%
ds
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
## get those countries start with a 
ds.loc[ds.Country.str.startswith('A')]
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 197       536389     22941        CHRISTMAS LIGHTS 10 REINDEER         6
# 198       536389     21622    VINTAGE UNION JACK CUSHION COVER         8
# 199       536389     21791  VINTAGE HEADS AND TAILS CARD GAME         12
# 200       536389    35004C     SET OF 3 COLOURED  FLYING DUCKS         6
# 201       536389    35004G          SET OF 3 GOLD FLYING DUCKS         4
# ...          ...       ...                                 ...       ...
# 536964    581232   15056BL             EDWARDIAN PARASOL BLACK        24
# 536965    581232    15056P              EDWARDIAN PARASOL PINK        12
# 536966    581232     22059       CERAMIC STRAWBERRY DESIGN MUG        24
# 536967    581232     22646  CERAMIC STRAWBERRY CAKE MONEY BANK        36
# 536968    581232      POST                             POSTAGE         4
#
#           InvoiceDate  UnitPrice  CustomerID    Country
# ...

# %%
## get those countries whose name starts with letter F and end with e
ds.loc[ds.Country.str.startswith('F') & ds.Country.str.endswith('e')]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 26        536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727        ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370     21883                 STARS GIFT TAPE         24
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID Country
# 26       12/1/10 8:45       3.75     12583.0  France
# ...

# %%
## get the countries whose name has 'ra'
ds.loc[ds.Country.str.contains('Un')]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541889    581585     22466       FAIRY TALE COTTAGE NIGHT LIGHT        12
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 541891    581586     23275     SET OF 3 HANGING OWLS OLLIE BEAK        24
# 541892    581586     21217        RED RETROSPOT ROUND CAKE TINS        24
# 541893    581586     20685                DOORMAT RED RETROSPOT        10
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
ds
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
## generate 10 values random
import numpy as np
ds.iloc[np.random.randint(0,541909,100)]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 51502     540646     22720    SET OF 3 CAKE TINS PANTRY DESIGN          1
# 197522    553913     21361             LOVE LARGE WOOD LETTERS          1
# 329304    565841     23238    SET OF 4 KNICK KNACK TINS LONDON          1
# 67865     541848    90160C     TURQ+RED BOUDICCA LARGE BRACELET         2
# 431680    573744     22577  WOODEN HEART CHRISTMAS SCANDINAVIAN        24
# ...          ...       ...                                  ...       ...
# 411263    572212     22805   BLUE DRAWER KNOB ACRYLIC EDWARDIAN        12
# 126169    547066     20728                  LUNCH BAG CARS BLUE        20
# 105263    545217     82484    WOOD BLACK BOARD ANT WHITE FINISH         1
# 17133     537683     84992       72 SWEETHEART FAIRY CAKE CASES        24
# 539553    581439     22250  DECORATION  BUTTERFLY  MAGIC GARDEN         2
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
## now aggregation

# %%
ds
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
ds.Quantity.mean()
# Out:
# 9.55224954743324

# %%
ds.Quantity.sum()
# Out:
# 5176450

# %%
ds.UnitPrice.sum()
# Out:
# 2498803.974

# %%
ds.UnitPrice.agg(['max','sum','min','mean',])
# Out:
# max     3.897000e+04
# sum     2.498804e+06
# min    -1.106206e+04
# mean    4.611114e+00
# Name: UnitPrice, dtype: float64

# %%
## multiple columns
ds[['UnitPrice','Quantity']].agg(['min','max'])
# Out:
#      UnitPrice  Quantity
# min  -11062.06    -80995
# max   38970.00     80995

# %% [markdown]
# # sort

# %%
ds
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
ds.sort_index(ascending=False,axis=1)
# Out:
#         UnitPrice StockCode  Quantity InvoiceNo    InvoiceDate  \
# 0            2.55    85123A         6    536365   12/1/10 8:26
# 1            3.39     71053         6    536365   12/1/10 8:26
# 2            2.75    84406B         8    536365   12/1/10 8:26
# 3            3.39    84029G         6    536365   12/1/10 8:26
# 4            3.39    84029E         6    536365   12/1/10 8:26
# ...           ...       ...       ...       ...            ...
# 541904       0.85     22613        12    581587  12/9/11 12:50
# 541905       2.10     22899         6    581587  12/9/11 12:50
# 541906       4.15     23254         4    581587  12/9/11 12:50
# 541907       4.15     23255         4    581587  12/9/11 12:50
# 541908       4.95     22138         3    581587  12/9/11 12:50
#
#                                 Description  CustomerID         Country
# 0        WHITE HANGING HEART T-LIGHT HOLDER     17850.0  United Kingdom
# ...

# %%
## sort by values

ds.sort_values(by=['Quantity','UnitPrice'],ascending=[True,False]).iloc[:10]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 540422   C581484     23843          PAPER CRAFT , LITTLE BIRDIE    -80995
# 61624    C541433     23166       MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 225529    556690     23005         printing smudges/thrown away     -9600
# 225530    556691     23005         printing smudges/thrown away     -9600
# 4287     C536757     84347  ROTATING SILVER ANGELS T-LIGHT HLDR     -9360
# 225528    556687     23003         Printing smudges/thrown away     -9058
# 115818    546152    72140F                           throw away     -5368
# 431381    573596    79323W               Unsaleable, destroyed.     -4830
# 341601    566768     16045                                  NaN     -3667
# 323458    565304     16259                                  NaN     -3167
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 540422    12/9/11 9:27       2.08     16446.0  United Kingdom
# ...

# %%
## nuique

# %%
ds.nunique()
# Out:
# InvoiceNo      25900
# StockCode       4070
# Description     4223
# Quantity         722
# InvoiceDate    23260
# UnitPrice       1630
# CustomerID      4372
# Country           38
# dtype: int64

# %%
print(ds['Country'].unique())
# Out:
# ['United Kingdom' 'France' 'Australia' 'Netherlands' 'Germany' 'Norway'
#  'EIRE' 'Switzerland' 'Spain' 'Poland' 'Portugal' 'Italy' 'Belgium'
#  'Lithuania' 'Japan' 'Iceland' 'Channel Islands' 'Denmark' 'Cyprus'
#  'Sweden' 'Austria' 'Israel' 'Finland' 'Bahrain' 'Greece' 'Hong Kong'
#  'Singapore' 'Lebanon' 'United Arab Emirates' 'Saudi Arabia'
#  'Czech Republic' 'Canada' 'Unspecified' 'Brazil' 'USA'
#  'European Community' 'Malta' 'RSA']

# %%
ds
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
## extract numerical columns and text columns
ds.select_dtypes(include=['number','object'])
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
## get aggregate
# find aggregate where we have country is france

ds[ds.Country=='France'].select_dtypes('number').agg(['min','max','mean'])
# Out:
#         Quantity    UnitPrice    CustomerID
# min  -250.000000     0.000000  12413.000000
# max   912.000000  4161.060000  14277.000000
# mean   12.911067     5.028864  12677.995996

# %%
# country wise summary

for c in ds.Country.unique():
    print(c)
    print("------------------------------------------")
    print(ds[ds.Country == c].select_dtypes('number').agg(['min','mean','max']))
    print("------------------------------------------")
# Out:
# United Kingdom
# ------------------------------------------
#           Quantity     UnitPrice    CustomerID
# min  -80995.000000 -11062.060000  12346.000000
# mean      8.605486      4.532422  15547.871368
# max   80995.000000  38970.000000  18287.000000
# ------------------------------------------
# France
# ------------------------------------------
#         Quantity    UnitPrice    CustomerID
# min  -250.000000     0.000000  12413.000000
# mean   12.911067     5.028864  12677.995996
# max   912.000000  4161.060000  14277.000000
# ------------------------------------------
# Australia
# ------------------------------------------
#          Quantity   UnitPrice    CustomerID
# min   -120.000000    0.000000  12386.000000
# mean    66.444003    3.220612  12464.656076
# max   1152.000000  350.000000  16321.000000
# ------------------------------------------
# Netherlands
# ------------------------------------------
#         Quantity   UnitPrice    CustomerID
# ...

# %%
# Out:
#        Quantity  UnitPrice  CustomerID
# min    1.000000   0.000000     12446.0
# mean   6.068966   4.277586     12446.0
# max   12.000000  14.950000     12446.0
